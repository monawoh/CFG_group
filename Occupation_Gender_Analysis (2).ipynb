# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read in datasets
all_persons = pd.read_csv('Occupation_Gender_All_Persons_16_21.csv')

# copy all_persons data set and print the first 5 rows
all_persons_copy = all_persons.copy()
all_persons_copy.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-88127aefb321> in <module>
#       1 # read in datasets
# ----> 2 all_persons = pd.read_csv('Occupation_Gender_All_Persons_16_21.csv')
#       3
#       4 # copy all_persons data set and print the first 5 rows
#       5 all_persons_copy = all_persons.copy()
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Occupation_Gender_All_Persons_16_21.csv'

# %%
# Data sets have integer or object(string) values
# We can see that 2 columns has categorical data and all the other columns are of a numeric type (int 64) with non-Null entries.
all_persons_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 9 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   Region                                                             60 non-null     object
#  1   Year                                                               60 non-null     object
#  2   Information Technology and Telecommunications                      60 non-null     int64
#  3   Specialist Managers                                                60 non-null     int64
#  4   Project and Programme Managers                                     60 non-null     int64
#  5   Business Analysts, Architects and System Designers                 60 non-null     int64
#  6   Programmers and Software Development Professionals                 60 non-null     int64
#  7   Web design and development professionals                           60 non-null     int64
#  8   Information Technology and Telecommunications Professionals n.e.c  60 non-null     int64
# dtypes: int64(7), object(2)
# memory usage: 4.3+ KB

# %%
# dataset consist of 60 rows and 9 columns

print(all_persons_copy.shape)
# Out:
# (60, 9)

# %%
# check labels for each column for  data set

print('all_persons', all_persons_copy.columns.values)
# Out:
# all_persons ['Region' 'Year' 'Information Technology and Telecommunications'
#  'Specialist Managers' 'Project and Programme Managers'
#  'Business Analysts, Architects and System Designers'
#  'Programmers and Software Development Professionals'
#  'Web design and development professionals'
#  'Information Technology and Telecommunications Professionals n.e.c']

# %% [markdown]
# ### Describe the datasets to get a statistical summary of the dataset

# %%
# examine data
all_persons_copy.describe()
# Out:
#        Information Technology and Telecommunications  Specialist Managers  \
# count                                      60.000000            60.000000
# mean                                     9536.666667         17335.000000
# std                                      8010.691302         12129.105281
# min                                         0.000000          1800.000000
# 25%                                      3875.000000          9875.000000
# 50%                                      7300.000000         14700.000000
# 75%                                     11800.000000         19725.000000
# max                                     33400.000000         50400.000000
#
#        Project and Programme Managers  \
# count                       60.000000
# mean                      6256.666667
# std                       4924.906148
# min                        600.000000
# 25%                       2575.000000
# 50%                       5100.000000
# 75%                       7925.000000
# max                      23600.000000
#
#        Business Analysts, Architects and System Designers  \
# count                                          60.000000
# mean                                        12451.666667
# std                                         10293.316767
# min                                          2000.000000
# 25%                                          5975.000000
# 50%                                          9650.000000
# 75%                                         15725.000000
# max                                         53800.000000
#
#        Programmers and Software Development Professionals  \
# count                                          60.000000
# mean                                        30566.666667
# std                                         23913.911040
# min                                          5600.000000
# 25%                                         14000.000000
# 50%                                         23650.000000
# 75%                                         33950.000000
# max                                        102300.000000
#
#        Web design and development professionals  \
# count                                 60.000000
# mean                                5385.000000
# std                                 3963.042189
# min                                    0.000000
# 25%                                 2500.000000
# 50%                                 4500.000000
# 75%                                 7300.000000
# max                                17600.000000
#
#        Information Technology and Telecommunications Professionals n.e.c
# count                                          60.000000
# mean                                        16893.333333
# std                                         13361.605337
# min                                          3700.000000
# 25%                                          7850.000000
# 50%                                         13200.000000
# 75%                                         18900.000000
# max                                         53300.000000

# %% [markdown]
# ### Need to remove the rows or columns with 0 values for analysis --> doesn't correlate with the rest of the data.
# ### There may have been values higher than zero but they have not been included

# %%
# drop rows with 0 values to get a more accurate descripition of all the datasets as 0 appears to be a 'min' value for all datasets and that is not a correct representation of the actual figure/count

# drop '0' values for all_persons
all_persons_copy = all_persons_copy.loc[(all_persons_copy['Information Technology and Telecommunications'] != 0) & 
                     (all_persons_copy['Web design and development professionals'] != 0)]


all_persons_copy.shape
# Out:
# (58, 9)

# %%
# examine the data again and perform a very simple explanatory analysis

all_persons_copy.describe()

'''
mean value is more than median across all the sectors

large difference between 75% and max value --> outliers?
'''
# Out:
# '\nmean value is more than median across all the sectors\n\nlarge difference between 75% and max value --> outliers?\n'

# %% [markdown]
# ### Analysis on All Persons Datasets

# %% [markdown]
# # Plotting Graphs

# %%
# Create a pivot_table indexed by Region then Year for each sector
all_persons_copy_pivot = pd.pivot_table(all_persons_copy,index=["Region","Year"])

all_persons_copy_pivot.head(10)
# Out:
#                          Business Analysts, Architects and System Designers  \
# Region        Year
# East          2016-2017                                              11500
#               2017-2018                                              15800
#               2018-2019                                              11500
#               2019-2020                                              11500
#               2020-2021                                              19900
# East Midlands 2016-2017                                               6000
#               2017-2018                                               7300
#               2018-2019                                               9700
#               2019-2020                                               9600
#               2020-2021                                               9300
#
#                          Information Technology and Telecommunications  \
# Region        Year
# East          2016-2017                                          13400
#               2017-2018                                          10100
#               2018-2019                                          13600
#               2019-2020                                          18000
#               2020-2021                                          16300
# East Midlands 2016-2017                                           5000
#               2017-2018                                           5400
#               2018-2019                                           8600
#               2019-2020                                           5500
#               2020-2021                                           7400
#
#                          Information Technology and Telecommunications Professionals n.e.c  \
# Region        Year
# East          2016-2017                                              19900
#               2017-2018                                              19500
#               2018-2019                                              24800
#               2019-2020                                              16200
#               2020-2021                                              23000
# East Midlands 2016-2017                                              10000
#               2017-2018                                               7100
#               2018-2019                                              10200
#               2019-2020                                              12600
#               2020-2021                                              13700
#
#                          Programmers and Software Development Professionals  \
# Region        Year
# East          2016-2017                                              28900
#               2017-2018                                              28700
#               2018-2019                                              38500
#               2019-2020                                              41100
#               2020-2021                                              47100
# East Midlands 2016-2017                                              19000
#               2017-2018                                              17300
#               2018-2019                                              16500
#               2019-2020                                              14700
#               2020-2021                                              22000
#
#                          Project and Programme Managers  Specialist Managers  \
# Region        Year
# East          2016-2017                            9900                18900
#               2017-2018                            9500                17800
#               2018-2019                            4300                17600
#               2019-2020                            5000                26100
#               2020-2021                            7600                21300
# East Midlands 2016-2017                            5100                12800
#               2017-2018                            5700                12500
#               2018-2019                            4600                14400
#               2019-2020                            4300                14900
#               2020-2021                            5500                17800
#
#                          Web design and development professionals
# Region        Year
# East          2016-2017                                      7600
#               2017-2018                                      4900
#               2018-2019                                      4500
#               2019-2020                                      7600
#               2020-2021                                      8700
# East Midlands 2016-2017                                      5300
#               2017-2018                                      2600
#               2018-2019                                      2500
#               2019-2020                                      1000
#               2020-2021                                      2600

# %%
# Difficult to interpret because there is a lot of data on one graph
# Good way to visualise the number of people in each sector in each region and to see the change from 2016-2021
# Needs to be split up to draw accurate insights

ax = all_persons_copy_pivot.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(50, 30)

plt.show()

# %%
# Easier to interpret than above but still too much data on one graph
# Although not optimal - because all the region and years are on the x-axis so not the best for interpreting

all_persons_copy_pivot[['Business Analysts, Architects and System Designers',
                          'Information Technology and Telecommunications',
            'Information Technology and Telecommunications Professionals n.e.c',
           'Programmers and Software Development Professionals',
           'Project and Programme Managers',
           'Specialist Managers', 'Web design and development professionals']].plot(kind='bar', figsize=(30,25), subplots=True, layout=(3,3))
# Out:
# array([[<AxesSubplot:title={'center':'Business Analysts, Architects and System Designers'}, xlabel='Region,Year'>,
#         <AxesSubplot:title={'center':'Information Technology and Telecommunications'}, xlabel='Region,Year'>,
#         <AxesSubplot:title={'center':'Information Technology and Telecommunications Professionals n.e.c'}, xlabel='Region,Year'>],
#        [<AxesSubplot:title={'center':'Programmers and Software Development Professionals'}, xlabel='Region,Year'>,
#         <AxesSubplot:title={'center':'Project and Programme Managers'}, xlabel='Region,Year'>,
#         <AxesSubplot:title={'center':'Specialist Managers'}, xlabel='Region,Year'>],
#        [<AxesSubplot:title={'center':'Web design and development professionals'}, xlabel='Region,Year'>,
#         <AxesSubplot:xlabel='Region,Year'>,
#         <AxesSubplot:xlabel='Region,Year'>]], dtype=object)

# %% [markdown]
# ### Create pivot tables for each sector Indexed by Region, columns = Year

# %%
#pivot table for Business Analysts, Architects and System Designers
BA_Arch_SD = all_persons_copy.pivot('Region','Year','Business Analysts, Architects and System Designers')

# view the pivot table
BA_Arch_SD
# Out:
# Year                      2016-2017  2017-2018  2018-2019  2019-2020  \
# Region
# East                        11500.0    15800.0    11500.0    11500.0
# East Midlands                6000.0     7300.0     9700.0     9600.0
# London                      18400.0    28800.0    26700.0    41200.0
# North East                   2500.0     2800.0     3900.0     2700.0
# North West                  10500.0     9600.0    10600.0    12000.0
# Northern Ireland                NaN     2000.0        NaN     2700.0
# Scotland                    10800.0    11000.0     7400.0     9100.0
# South East                  27600.0    27900.0    25800.0    31700.0
# South West                  10300.0     8600.0     8900.0    10700.0
# Wales                        3900.0     3600.0     2400.0     3600.0
# West Midlands                6500.0     7600.0    13100.0    12000.0
# Yorkshire and The Humber     8500.0     6100.0     7600.0     8900.0
#
# Year                      2020-2021
# Region
# East                        19900.0
# East Midlands                9300.0
# London                      53800.0
# North East                   4000.0
# North West                  19300.0
# Northern Ireland             5200.0
# Scotland                    15700.0
# South East                  32800.0
# South West                  16900.0
# Wales                        5900.0
# West Midlands               16300.0
# Yorkshire and The Humber    13000.0

# %%
# bar plot based on the pivot table - Business Analysts, Architects and System Designers
ax = BA_Arch_SD.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)
plt.title('Business Analysts, Architects and System Designers')

plt.show()

# comparing across the same grouping of bars

# %%
# pivot table for Information Technology and Telecommunications
IT_telcomm = all_persons_copy.pivot('Region','Year','Information Technology and Telecommunications')

# view the pivot table
IT_telcomm
# Out:
# Year                      2016-2017  2017-2018  2018-2019  2019-2020  \
# Region
# East                        13400.0    10100.0    13600.0    18000.0
# East Midlands                5000.0     5400.0     8600.0     5500.0
# London                      24200.0    22400.0    24600.0    20100.0
# North East                   2500.0     2000.0     2100.0     2000.0
# North West                   6200.0     7400.0     9600.0    10000.0
# Northern Ireland                NaN     1200.0        NaN      600.0
# Scotland                     6400.0     4000.0     6000.0     6100.0
# South East                  22800.0    23200.0    24100.0    25900.0
# South West                  10100.0     9800.0     6400.0     9900.0
# Wales                        2300.0     1400.0     3500.0     2400.0
# West Midlands                7200.0     4400.0     4400.0     7900.0
# Yorkshire and The Humber     7000.0     6800.0     7600.0    11700.0
#
# Year                      2020-2021
# Region
# East                        16300.0
# East Midlands                7400.0
# London                      33400.0
# North East                    800.0
# North West                  10700.0
# Northern Ireland             2700.0
# Scotland                     4000.0
# South East                  27900.0
# South West                   7800.0
# Wales                        2700.0
# West Midlands               12100.0
# Yorkshire and The Humber     8700.0

# %%
# bar plot based on the pivot table Information Technology and Telecommunications
ax = IT_telcomm.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)
plt.title('Information Technology and Telecommunications')

plt.show()

# %%
# pivot table for Information Technology and Telecommunications Professionals n.e.c
IT_telcomm_nec = all_persons_copy.pivot('Region','Year','Information Technology and Telecommunications Professionals n.e.c')

# view the pivot table
IT_telcomm_nec
# Out:
# Year                      2016-2017  2017-2018  2018-2019  2019-2020  \
# Region
# East                        19900.0    19500.0    24800.0    16200.0
# East Midlands               10000.0     7100.0    10200.0    12600.0
# London                      50100.0    44800.0    45800.0    41400.0
# North East                   4100.0     4600.0     5800.0     5300.0
# North West                  12000.0    16500.0    16500.0    18700.0
# Northern Ireland                NaN     4500.0        NaN     4000.0
# Scotland                    12400.0    11600.0     8600.0    11300.0
# South East                  36400.0    39600.0    41300.0    42800.0
# South West                  17200.0    13400.0    10700.0    14600.0
# Wales                        5100.0     4500.0     3800.0     6100.0
# West Midlands               15400.0    13000.0    15000.0    14200.0
# Yorkshire and The Humber    11000.0     9000.0     8900.0    11900.0
#
# Year                      2020-2021
# Region
# East                        23000.0
# East Midlands               13700.0
# London                      53300.0
# North East                   5100.0
# North West                  20200.0
# Northern Ireland             8100.0
# Scotland                    14200.0
# South East                  43700.0
# South West                  16200.0
# Wales                        4000.0
# West Midlands               18600.0
# Yorkshire and The Humber    13700.0

# %%
# bar plot based on the pivot table Information Technology and Telecommunications n.e.c
ax = IT_telcomm_nec.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)
plt.title('Information Technology and Telecommunications Professionals n.e.c')

plt.show()

# %%
# pivot table for Programmers and Software Development Professionals
Prog_SoftDevProf = all_persons_copy.pivot('Region','Year','Programmers and Software Development Professionals')

# view the pivot table
Prog_SoftDevProf
# Out:
# Year                      2016-2017  2017-2018  2018-2019  2019-2020  \
# Region
# East                        28900.0    28700.0    38500.0    41100.0
# East Midlands               19000.0    17300.0    16500.0    14700.0
# London                      68900.0    76000.0    92500.0    96300.0
# North East                   8800.0     7300.0     8600.0     9300.0
# North West                  20500.0    23600.0    30600.0    33800.0
# Northern Ireland                NaN     9400.0        NaN     9200.0
# Scotland                    25600.0    27100.0    23800.0    25300.0
# South East                  59400.0    61900.0    65600.0    77000.0
# South West                  23200.0    22000.0    30800.0    27200.0
# Wales                        7800.0     9300.0     9200.0     9900.0
# West Midlands               16100.0    23700.0    21400.0    32200.0
# Yorkshire and The Humber    15100.0    18800.0    20000.0    21600.0
#
# Year                      2020-2021
# Region
# East                        47100.0
# East Midlands               22000.0
# London                     102300.0
# North East                  11800.0
# North West                  42400.0
# Northern Ireland            11100.0
# Scotland                    34400.0
# South East                  74400.0
# South West                  32800.0
# Wales                       11900.0
# West Midlands               29700.0
# Yorkshire and The Humber    29000.0

# %%
# bar plot based on the pivot table Programmers and Software Development Professionals
ax = Prog_SoftDevProf.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)
plt.title('Programmers and Software Development Professionals')

plt.show()

# %%
# pivot table for Project and Programme Managers
Project_ProgManagers = all_persons_copy.pivot('Region','Year','Project and Programme Managers')

# view the pivot table
Project_ProgManagers
# Out:
# Year                      2016-2017  2017-2018  2018-2019  2019-2020  \
# Region
# East                         9900.0     9500.0     4300.0     5000.0
# East Midlands                5100.0     5700.0     4600.0     4300.0
# London                      18200.0    15500.0    10300.0    23600.0
# North East                   2300.0     1400.0     1100.0      600.0
# North West                   6500.0     7100.0     5100.0     5100.0
# Northern Ireland                NaN     2100.0        NaN     2000.0
# Scotland                     5700.0     4900.0     5600.0     3600.0
# South East                  16300.0    13300.0     8000.0    12000.0
# South West                   7700.0     3200.0     3100.0     9000.0
# Wales                        2100.0     2500.0     1100.0     1500.0
# West Midlands                3300.0     3900.0     2700.0     7000.0
# Yorkshire and The Humber     4300.0     5800.0     1600.0     5000.0
#
# Year                      2020-2021
# Region
# East                         7600.0
# East Midlands                5500.0
# London                      13500.0
# North East                    800.0
# North West                   8500.0
# Northern Ireland             2600.0
# Scotland                     5700.0
# South East                  19500.0
# South West                   8800.0
# Wales                        1000.0
# West Midlands                7900.0
# Yorkshire and The Humber     7300.0

# %%
# bar plot based on the pivot table Project and Programme Managers
ax = Project_ProgManagers.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)
plt.title('Project and Programme Managers')

plt.show()

# %%
# pivot table for Specialist Managers
Specialist_Managers = all_persons_copy.pivot('Region','Year','Specialist Managers')

# view the pivot table
Specialist_Managers
# Out:
# Year                      2016-2017  2017-2018  2018-2019  2019-2020  \
# Region
# East                        18900.0    17800.0    17600.0    26100.0
# East Midlands               12800.0    12500.0    14400.0    14900.0
# London                      33700.0    36400.0    43800.0    43600.0
# North East                   5100.0     4600.0     5100.0     5700.0
# North West                  15900.0    17300.0    17000.0    19400.0
# Northern Ireland                NaN     1800.0        NaN     2000.0
# Scotland                    10600.0    14000.0    10600.0    14000.0
# South East                  41000.0    33800.0    47700.0    33500.0
# South West                  15000.0    12500.0    14300.0    13500.0
# Wales                        5900.0     5700.0     7700.0     6700.0
# West Midlands               13200.0    12700.0    11800.0    17200.0
# Yorkshire and The Humber    11100.0    15900.0    14500.0    16900.0
#
# Year                      2020-2021
# Region
# East                        21300.0
# East Midlands               17800.0
# London                      50400.0
# North East                   5800.0
# North West                  23600.0
# Northern Ireland             3600.0
# Scotland                    20700.0
# South East                  42100.0
# South West                  16600.0
# Wales                        6200.0
# West Midlands               19300.0
# Yorkshire and The Humber    21200.0

# %%
# bar plot based on the pivot table Specialist Managers
ax = Specialist_Managers.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)
plt.title('Specialist Managers')

plt.show()

# %%
# pivot table for Web design and development professionals 
Web_design_dev_prof = all_persons_copy.pivot('Region','Year','Web design and development professionals')

# view the pivot table
Web_design_dev_prof
# Out:
# Year                      2016-2017  2017-2018  2018-2019  2019-2020  \
# Region
# East                         7600.0     4900.0     4500.0     7600.0
# East Midlands                5300.0     2600.0     2500.0     1000.0
# London                      13300.0    13700.0    14400.0    12400.0
# North East                   2500.0     2300.0     2500.0     2400.0
# North West                   6100.0     5200.0     3700.0     7200.0
# Northern Ireland                NaN      600.0        NaN     1700.0
# Scotland                     5600.0     4200.0     6100.0     4800.0
# South East                  15300.0     9900.0     8100.0     8200.0
# South West                   4800.0     5000.0     6600.0     8700.0
# Wales                        2500.0     1400.0     2300.0     2000.0
# West Midlands                2500.0     3900.0     6000.0     3900.0
# Yorkshire and The Humber     4500.0     4400.0     3900.0     2700.0
#
# Year                      2020-2021
# Region
# East                         8700.0
# East Midlands                2600.0
# London                      17600.0
# North East                   2100.0
# North West                   8000.0
# Northern Ireland              700.0
# Scotland                     1900.0
# South East                  11300.0
# South West                   6500.0
# Wales                        1600.0
# West Midlands                3600.0
# Yorkshire and The Humber     6100.0

# %%
# bar plot based on the pivot table Web design and development professionals
ax = Web_design_dev_prof.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)
plt.title('Web design and development professionals')

plt.show()

# %% [markdown]
# ## Analysis on Males and Females Datasets

# %%
# read in datasets for females and males 
females = pd.read_csv('./data/Occupation_Gender_Females_16_21.csv')
males = pd.read_csv('./data/Occupation_Gender_Males_16_21.csv')

# %%
### Copy the databases

# %%
# copy females data set and print the first 5 rows
females_copy = females.copy()
females_copy.head()
# Out:
#   Region       Year  Information Technology and Telecommunications  \
# 0   East  2016-2017                                           1600
# 1   East  2016-2017                                            700
# 2   East  2016-2017                                           1300
# 3   East  2016-2017                                            900
# 4   East  2016-2017                                           1100
#
#    Specialist Managers  Project and Programme Managers  \
# 0                 3100                            3300
# 1                 4100                            2200
# 2                 2500                            1500
# 3                 5100                            1300
# 4                 7300                            2100
#
#    Business Analysts, Architects and System Designers  \
# 0                                               2600
# 1                                               2100
# 2                                               2000
# 3                                               2200
# 4                                               5500
#
#    Programmers and Software Development Professionals  \
# 0                                               3800
# 1                                               4900
# 2                                               5700
# 3                                               2300
# 4                                               6000
#
#    Web design and development professionals  \
# 0                                      2000
# 1                                      1100
# 2                                      1000
# 3                                      1400
# 4                                      1400
#
#    Information Technology and Telecommunications Professionals n.e.c
# 0                                               2300
# 1                                               2600
# 2                                               3200
# 3                                               4000
# 4                                               3400

# %%
# copy males data set and print the first 5 rows
males_copy = males.copy()
males_copy.head()
# Out:
#   Region       Year  Information Technology and Telecommunications  \
# 0   East  2016-2017                                          11800
# 1   East  2017-2018                                           9400
# 2   East  2018-2019                                          12300
# 3   East  2019-2020                                          17100
# 4   East  2020-2021                                          15200
#
#    Specialist Managers  Project and Programme Managers  \
# 0                15800                            6600
# 1                13700                            7300
# 2                15100                            2800
# 3                21000                            3700
# 4                14000                            5500
#
#    Business Analysts, Architects and System Designers  \
# 0                                               8900
# 1                                              13700
# 2                                               9500
# 3                                               9300
# 4                                              14400
#
#    Programmers and Software Development Professionals  \
# 0                                              25100
# 1                                              23800
# 2                                              32800
# 3                                              38800
# 4                                              41100
#
#    Web design and development professionals  \
# 0                                      5600
# 1                                      3800
# 2                                      3500
# 3                                      6200
# 4                                      7300
#
#    Information Technology and Telecommunications Professionals n.e.c
# 0                                              17600
# 1                                              16900
# 2                                              21600
# 3                                              12200
# 4                                              19600

# %%
# Both Data sets ahve integer or object(string) values
# We can see that 2 columns has categorical data and all the other columns are of a numeric type (int 64) with non-Null entries.

females_copy.info()

males_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 9 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   Region                                                             60 non-null     object
#  1   Year                                                               60 non-null     object
#  2   Information Technology and Telecommunications                      60 non-null     int64
#  3   Specialist Managers                                                60 non-null     int64
#  4   Project and Programme Managers                                     60 non-null     int64
#  5   Business Analysts, Architects and System Designers                 60 non-null     int64
#  6   Programmers and Software Development Professionals                 60 non-null     int64
#  7   Web design and development professionals                           60 non-null     int64
#  8   Information Technology and Telecommunications Professionals n.e.c  60 non-null     int64
# dtypes: int64(7), object(2)
# memory usage: 4.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 9 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   Region                                                             60 non-null     object
#  1   Year                                                               60 non-null     object
#  2   Information Technology and Telecommunications                      60 non-null     int64
#  3   Specialist Managers                                                60 non-null     int64
#  4   Project and Programme Managers                                     60 non-null     int64
#  5   Business Analysts, Architects and System Designers                 60 non-null     int64
#  6   Programmers and Software Development Professionals                 60 non-null     int64
#  7   Web design and development professionals                           60 non-null     int64
#  8   Information Technology and Telecommunications Professionals n.e.c  60 non-null     int64
# dtypes: int64(7), object(2)
# memory usage: 4.3+ KB

# %%
# Both datasets consist of 60 rows and 9 columns
print(females_copy.shape)

print(males_copy.shape)
# Out:
# (60, 9)
# (60, 9)

# %%
# check labels for each column for all data sets

print('females', females_copy.columns.values)

print('males', males_copy.columns.values)
# Out:
# females ['Region' 'Year' 'Information Technology and Telecommunications'
#  'Specialist Managers' 'Project and Programme Managers'
#  'Business Analysts, Architects and System Designers'
#  'Programmers and Software Development Professionals'
#  'Web design and development professionals'
#  'Information Technology and Telecommunications Professionals n.e.c']
# males ['Region' 'Year' 'Information Technology and Telecommunications'
#  'Specialist Managers' 'Project and Programme Managers'
#  'Business Analysts, Architects and System Designers'
#  'Programmers and Software Development Professionals'
#  'Web design and development professionals'
#  'Information Technology and Telecommunications Professionals n.e.c']

# %%
### Describe the datasets to get a statistical summary of the females datasets 

females_copy.head(10)

females_copy.describe()
# Out:
#        Information Technology and Telecommunications  Specialist Managers  \
# count                                      60.000000            60.000000
# mean                                     1170.000000          3551.666667
# std                                      1043.023636          2733.873620
# min                                         0.000000           100.000000
# 25%                                       475.000000          1775.000000
# 50%                                       850.000000          3050.000000
# 75%                                      1625.000000          4300.000000
# max                                      4500.000000         14800.000000
#
#        Project and Programme Managers  \
# count                       60.000000
# mean                      1731.666667
# std                       1541.459980
# min                          0.000000
# 25%                        775.000000
# 50%                       1300.000000
# 75%                       2200.000000
# max                       6400.000000
#
#        Business Analysts, Architects and System Designers  \
# count                                          60.000000
# mean                                         2133.333333
# std                                          2015.000245
# min                                           200.000000
# 25%                                           875.000000
# 50%                                          1850.000000
# 75%                                          2425.000000
# max                                         11900.000000
#
#        Programmers and Software Development Professionals  \
# count                                          60.000000
# mean                                         4186.666667
# std                                          3835.139344
# min                                           300.000000
# 25%                                          1400.000000
# 50%                                          2950.000000
# 75%                                          5025.000000
# max                                         17200.000000
#
#        Web design and development professionals  \
# count                                 60.000000
# mean                                1443.333333
# std                                 1604.692976
# min                                    0.000000
# 25%                                  400.000000
# 50%                                  950.000000
# 75%                                 1650.000000
# max                                 8100.000000
#
#        Information Technology and Telecommunications Professionals n.e.c
# count                                          60.000000
# mean                                         3135.000000
# std                                          3178.680304
# min                                             0.000000
# 25%                                          1300.000000
# 50%                                          2350.000000
# 75%                                          3400.000000
# max                                         16500.000000

# %%
### Describe the datasets to get a statistical summary of the males dataset 

males_copy.head(10)

males_copy.describe()
# Out:
#        Information Technology and Telecommunications  Specialist Managers  \
# count                                      60.000000            60.000000
# mean                                     8366.666667         13783.333333
# std                                      7147.351451          9756.200404
# min                                         0.000000          1600.000000
# 25%                                      2925.000000          6800.000000
# 50%                                      6300.000000         11500.000000
# 75%                                     10925.000000         15650.000000
# max                                     28900.000000         39800.000000
#
#        Project and Programme Managers  \
# count                       60.000000
# mean                      4525.000000
# std                       3610.231459
# min                          0.000000
# 25%                       2100.000000
# 50%                       3500.000000
# 75%                       6600.000000
# max                      18300.000000
#
#        Business Analysts, Architects and System Designers  \
# count                                          60.000000
# mean                                        10318.333333
# std                                          8510.541652
# min                                          1300.000000
# 25%                                          4500.000000
# 50%                                          8100.000000
# 75%                                         13325.000000
# max                                         41900.000000
#
#        Programmers and Software Development Professionals  \
# count                                          60.000000
# mean                                        26380.000000
# std                                         20281.709218
# min                                          5300.000000
# 25%                                         12250.000000
# 50%                                         20150.000000
# 75%                                         28800.000000
# max                                         85100.000000
#
#        Web design and development professionals  \
# count                                 60.000000
# mean                                3941.666667
# std                                 2598.388788
# min                                    0.000000
# 25%                                 1900.000000
# 50%                                 3500.000000
# 75%                                 5525.000000
# max                                10700.000000
#
#        Information Technology and Telecommunications Professionals n.e.c
# count                                          60.000000
# mean                                        13758.333333
# std                                         10687.649956
# min                                          2600.000000
# 25%                                          6100.000000
# 50%                                         10750.000000
# 75%                                         15025.000000
# max                                         41600.000000

# %%
# drop '0' values for females

females_copy = females_copy.loc[
    (females_copy['Information Technology and Telecommunications'] != 0) & 
                     (females_copy['Web design and development professionals'] != 0) 
    & (females_copy['Project and Programme Managers'] !=0 ) 
    & (females_copy['Information Technology and Telecommunications Professionals n.e.c'] != 0)]

# check the rows & cols
females_copy.shape
# Out:
# (49, 9)

# %%
# drop '0' values for males

males_copy = males_copy.loc[
    (males_copy['Information Technology and Telecommunications'] != 0) & 
                     (males_copy['Web design and development professionals'] != 0) 
    & (males_copy['Project and Programme Managers'] !=0 )]

# check the rows & cols
males_copy.shape
# Out:
# (56, 9)

# %%
females_copy.describe()

males_copy.describe()
# Out:
#        Information Technology and Telecommunications  Specialist Managers  \
# count                                      56.000000            56.000000
# mean                                     8882.142857         14548.214286
# std                                      7119.936341          9649.907980
# min                                       600.000000          1600.000000
# 25%                                      3800.000000          8850.000000
# 50%                                      6500.000000         12250.000000
# 75%                                     11200.000000         15950.000000
# max                                     28900.000000         39800.000000
#
#        Project and Programme Managers  \
# count                       56.000000
# mean                      4757.142857
# std                       3621.393862
# min                        600.000000
# 25%                       2350.000000
# 50%                       3650.000000
# 75%                       6625.000000
# max                      18300.000000
#
#        Business Analysts, Architects and System Designers  \
# count                                          56.000000
# mean                                        10869.642857
# std                                          8542.171741
# min                                          1300.000000
# 25%                                          5350.000000
# 50%                                          8500.000000
# 75%                                         13725.000000
# max                                         41900.000000
#
#        Programmers and Software Development Professionals  \
# count                                          56.000000
# mean                                        27707.142857
# std                                         20345.621438
# min                                          6800.000000
# 25%                                         14650.000000
# 50%                                         20650.000000
# 75%                                         31375.000000
# max                                         85100.000000
#
#        Web design and development professionals  \
# count                                 56.000000
# mean                                4182.142857
# std                                 2516.571054
# min                                  600.000000
# 25%                                 2100.000000
# 50%                                 3650.000000
# 75%                                 5725.000000
# max                                10700.000000
#
#        Information Technology and Telecommunications Professionals n.e.c
# count                                          56.000000
# mean                                        14458.928571
# std                                         10719.121008
# min                                          2600.000000
# 25%                                          8350.000000
# 50%                                         11150.000000
# 75%                                         17050.000000
# max                                         41600.000000

# %% [markdown]
# <p>
#
# Observation between Males and Females dataset
#
# All statistical values for the males datasest is considerbly higher than that of the females dataset.
#
# The mean is higher compared to median for females and males
#
# The difference between 75% and max higher for males and females
#
# Overall there are consideraly more males than females in various roles in the field of Technology across these sectors
#
#
# </p>

# %% [markdown]
# # Plotting Graphs

# %% [markdown]
# ### Females: Create pivot tables for each sector Index = Region, Columns = Year  & plot graphs

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-01e3ce2f7083> in <module>
# ----> 1 drop_duplicates
#
# NameError: name 'drop_duplicates' is not defined

# %%
#pivot table for Business Analysts, Architects and System Designers
BA_Arch_SD = females_copy.pivot('Region','Year','Business Analysts, Architects and System Designers')

# view the pivot table
BA_Arch_SD
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-648ad7e25abc> in <module>
#       1 #pivot table for Business Analysts, Architects and System Designers
# ----> 2 BA_Arch_SD = females_copy.pivot('Region','Year','Business Analysts, Architects and System Designers')
#       3
#       4 # view the pivot table
#       5 BA_Arch_SD
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    6672         from pandas.core.reshape.pivot import pivot
#    6673
# -> 6674         return pivot(self, index=index, columns=columns, values=values)
#    6675
#    6676     _shared_docs[
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     475         else:
#     476             indexed = data._constructor_sliced(data[values]._values, index=index)
# --> 477     return indexed.unstack(columns)
#     478
#     479
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
#    3888         from pandas.core.reshape.reshape import unstack
#    3889
# -> 3890         return unstack(self, level, fill_value)
#    3891
#    3892     # ----------------------------------------------------------------------
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in unstack(obj, level, fill_value)
#     422         if is_extension_array_dtype(obj.dtype):
#     423             return _unstack_extension_series(obj, level, fill_value)
# --> 424         unstacker = _Unstacker(
#     425             obj.index, level=level, constructor=obj._constructor_expanddim,
#     426         )
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in __init__(self, index, level, constructor)
#     118             raise ValueError("Unstacked DataFrame is too big, causing int32 overflow")
#     119
# --> 120         self._make_selectors()
#     121
#     122     @cache_readonly
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\reshape.py in _make_selectors(self)
#     167
#     168         if mask.sum() < len(self.index):
# --> 169             raise ValueError("Index contains duplicate entries, cannot reshape")
#     170
#     171         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
# bar plot based on the pivot table - Business Analysts, Architects and System Designers
ax = BA_Arch_SD.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)

plt.title('Business Analysts, Architects and System Designers')

plt.show()

# comparing across the same grouping of bars

# %%
#corrlation Table of BA analyst and Architects between all years
corrmat = BA_Arch_SD.corr()
corrmat

# %%
sns.heatmap(corrmat, vmax=1., square=False).xaxis.tick_bottom()

# %%
# pivot table for Information Technology and Telecommunications
IT_telcomm = females_copy.pivot('Region','Year','Information Technology and Telecommunications')

# view the pivot table
IT_telcomm
# Out:
# Year                      2016-2017  2017-2018  2018-2019  2019-2020  \
# Region
# East                         1600.0      700.0     1300.0      900.0
# East Midlands                1200.0        NaN     2400.0        NaN
# London                       1900.0     3600.0     3500.0     3500.0
# North East                    200.0      400.0        NaN        NaN
# North West                    600.0      900.0     1900.0      200.0
# Northern Ireland                NaN        NaN        NaN        NaN
# Scotland                     1500.0     1300.0      800.0     1100.0
# South East                   2400.0     2100.0     1700.0     3600.0
# South West                   1200.0      700.0      600.0     1500.0
# Wales                         400.0        NaN      500.0      600.0
# West Midlands                 700.0      700.0        NaN     1200.0
# Yorkshire and The Humber     2000.0      700.0     1100.0      800.0
#
# Year                      2020-2021
# Region
# East                         1100.0
# East Midlands                1000.0
# London                       4500.0
# North East                      NaN
# North West                   1800.0
# Northern Ireland              600.0
# Scotland                      200.0
# South East                   3100.0
# South West                    800.0
# Wales                         600.0
# West Midlands                1100.0
# Yorkshire and The Humber      700.0

# %%
# bar plot based on the pivot table Information Technology and Telecommunications
ax = IT_telcomm.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)

plt.title('Information Technology and Telecommunications')

plt.show()

# %%
#corrlation Table of IT TELECOM between all years
corrmat = IT_telcomm.corr()
corrmat

# %%
sns.heatmap(corrmat, vmax=1., square=False).xaxis.tick_bottom()

# %%
# pivot table for Information Technology and Telecommunications Professionals n.e.c
IT_telcomm_nec = females_copy.pivot('Region','Year','Information Technology and Telecommunications Professionals n.e.c')

# view the pivot table
IT_telcomm_nec
# Out:
# Year                      2016-2017  2017-2018  2018-2019  2019-2020  \
# Region
# East                         2300.0     2600.0     3200.0     4000.0
# East Midlands                 400.0        NaN     1700.0        NaN
# London                       8500.0     9100.0     7800.0    14100.0
# North East                    400.0      400.0        NaN        NaN
# North West                   2400.0     3300.0     3000.0     5900.0
# Northern Ireland                NaN        NaN        NaN        NaN
# Scotland                     1800.0     3000.0      700.0     2400.0
# South East                   3700.0     5400.0     5300.0     6400.0
# South West                   2800.0     2200.0     1300.0     2000.0
# Wales                         800.0        NaN      500.0     1300.0
# West Midlands                2800.0     2100.0        NaN     1700.0
# Yorkshire and The Humber     1800.0      500.0     2400.0     2200.0
#
# Year                      2020-2021
# Region
# East                         3400.0
# East Midlands                3400.0
# London                      16500.0
# North East                      NaN
# North West                   2700.0
# Northern Ireland             1800.0
# Scotland                     4300.0
# South East                  10300.0
# South West                   2700.0
# Wales                         700.0
# West Midlands                4900.0
# Yorkshire and The Humber     2600.0

# %%
# bar plot based on the pivot table Information Technology and Telecommunications n.e.c
ax = IT_telcomm_nec.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)

plt.title('Information Technology and Telecommunications Professionals n.e.c')

plt.show()

# %%
#corrlation Table of IT TELECOM nec between all years
corrmat = IT_telcomm_nec.corr()
corrmat

# %%
sns.heatmap(corrmat, vmax=1., square=False).xaxis.tick_bottom()

# %%
# pivot table for Programmers and Software Development Professionals
Prog_SoftDevProf = females_copy.pivot('Region','Year','Programmers and Software Development Professionals')

# view the pivot table
Prog_SoftDevProf
# Out:
# Year                      2016-2017  2017-2018  2018-2019  2019-2020  \
# Region
# East                         3800.0     4900.0     5700.0     2300.0
# East Midlands                3700.0        NaN     2000.0        NaN
# London                       7600.0    10700.0    12900.0    14700.0
# North East                    600.0      400.0        NaN        NaN
# North West                   2900.0     4200.0     5000.0     2900.0
# Northern Ireland                NaN        NaN        NaN        NaN
# Scotland                     3300.0     5100.0     4900.0     4700.0
# South East                  11100.0     7400.0     8900.0    10900.0
# South West                   3100.0     1800.0     3500.0     2300.0
# Wales                        1000.0        NaN     1400.0     1000.0
# West Midlands                1400.0     3000.0        NaN     5000.0
# Yorkshire and The Humber     1300.0     2700.0      900.0     2900.0
#
# Year                      2020-2021
# Region
# East                         6000.0
# East Midlands                3100.0
# London                      17200.0
# North East                      NaN
# North West                   4200.0
# Northern Ireland             1000.0
# Scotland                     6300.0
# South East                  13600.0
# South West                   5900.0
# Wales                        2200.0
# West Midlands                3100.0
# Yorkshire and The Humber     2500.0

# %%
# bar plot based on the pivot table Programmers and Software Development Professionals
ax = Prog_SoftDevProf.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)

plt.title('Programmers and Software Development Professionals')

plt.show()

# %%
#corrlation Prog_SoftDevProf between all years
corrmat =  Prog_SoftDevProf.corr()
corrmat

# %%
sns.heatmap(corrmat, vmax=1., square=False).xaxis.tick_bottom()

# %%
# pivot table for Project and Programme Managers
Project_ProgManagers = females_copy.pivot('Region','Year','Project and Programme Managers')

# view the pivot table
Project_ProgManagers
# Out:
# Year                      2016-2017  2017-2018  2018-2019  2019-2020  \
# Region
# East                         3300.0     2200.0     1500.0     1300.0
# East Midlands                 900.0        NaN     1700.0        NaN
# London                       6400.0     6000.0     2400.0     5300.0
# North East                    600.0      300.0        NaN        NaN
# North West                    900.0     2000.0     2100.0     1500.0
# Northern Ireland                NaN        NaN        NaN        NaN
# Scotland                     1500.0     1900.0     1300.0     1100.0
# South East                   4200.0     4300.0     1300.0     2800.0
# South West                   1100.0      800.0      900.0     1400.0
# Wales                         300.0        NaN      300.0      500.0
# West Midlands                1100.0     1200.0        NaN     2600.0
# Yorkshire and The Humber      800.0     1900.0      200.0     1600.0
#
# Year                      2020-2021
# Region
# East                         2100.0
# East Midlands                1800.0
# London                       6400.0
# North East                      NaN
# North West                   1700.0
# Northern Ireland              500.0
# Scotland                     2900.0
# South East                   4300.0
# South West                   2200.0
# Wales                         300.0
# West Midlands                1000.0
# Yorkshire and The Humber     2300.0

# %%
# bar plot based on the pivot table Project and Programme Managers
ax = Project_ProgManagers.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)

plt.title('Project and Programme Managers')

plt.show()

# %%
#corrlation Project_ProgManagers between all years
corrmat =  Project_ProgManagers.corr()
corrmat

# %%
sns.heatmap(corrmat, vmax=1., square=False).xaxis.tick_bottom()

# %%
# pivot table for Specialist Managers
Specialist_Managers = females_copy.pivot('Region','Year','Specialist Managers')

# view the pivot table
Specialist_Managers
# Out:
# Year                      2016-2017  2017-2018  2018-2019  2019-2020  \
# Region
# East                         3100.0     4100.0     2500.0     5100.0
# East Midlands                1900.0        NaN     4100.0        NaN
# London                       7100.0     7100.0     6700.0    11300.0
# North East                   1000.0     1700.0        NaN        NaN
# North West                   3200.0     3700.0     3900.0     3900.0
# Northern Ireland                NaN        NaN        NaN        NaN
# Scotland                     2200.0     3900.0     1600.0     2500.0
# South East                   5200.0     4300.0     7900.0     7100.0
# South West                   2700.0     2100.0     2800.0     3600.0
# Wales                         900.0        NaN     1800.0      900.0
# West Midlands                2700.0     2500.0        NaN     2400.0
# Yorkshire and The Humber     3400.0     4400.0     3000.0     1500.0
#
# Year                      2020-2021
# Region
# East                         7300.0
# East Midlands                3700.0
# London                      14800.0
# North East                      NaN
# North West                   6600.0
# Northern Ireland              400.0
# Scotland                     4300.0
# South East                   8000.0
# South West                   4000.0
# Wales                        2000.0
# West Midlands                3700.0
# Yorkshire and The Humber     3600.0

# %%
# bar plot based on the pivot table Specialist Managers
ax = Specialist_Managers.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)

plt.title('Specialist Managers')

plt.show()

# %%
#corrlation Specialist_Managers between all years
corrmat = Specialist_Managers.corr()
corrmat

# %%
sns.heatmap(corrmat, vmax=1., square=False).xaxis.tick_bottom()

# %%
# pivot table for Web design and development professionals 
Web_design_dev_prof = females_copy.pivot('Region','Year','Web design and development professionals')

# view the pivot table
Web_design_dev_prof
# Out:
# Year                      2016-2017  2017-2018  2018-2019  2019-2020  \
# Region
# East                         2000.0     1100.0     1000.0     1400.0
# East Midlands                1300.0        NaN      700.0        NaN
# London                       4700.0     5900.0     6100.0     2700.0
# North East                    400.0      400.0        NaN        NaN
# North West                    800.0      500.0     1000.0      800.0
# Northern Ireland                NaN        NaN        NaN        NaN
# Scotland                     2500.0     1300.0     1600.0     1600.0
# South East                   4600.0     3200.0     2000.0     2700.0
# South West                   1300.0     1200.0     1500.0      700.0
# Wales                         400.0        NaN      100.0      400.0
# West Midlands                1100.0      200.0        NaN     1300.0
# Yorkshire and The Humber      900.0      600.0      900.0      600.0
#
# Year                      2020-2021
# Region
# East                         1400.0
# East Midlands                 700.0
# London                       8100.0
# North East                      NaN
# North West                   1900.0
# Northern Ireland              700.0
# Scotland                      100.0
# South East                   3000.0
# South West                   2500.0
# Wales                         200.0
# West Midlands                 400.0
# Yorkshire and The Humber     1600.0

# %%
# bar plot based on the pivot table Web design and development professionals
ax = Web_design_dev_prof.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)

plt.title('Web design and development professionals')

plt.show()

# %%
#corrlation Web_design_developers between all years
corrmat =  Web_design_dev_prof.corr()
corrmat

# %%
sns.heatmap(corrmat, vmax=1., square=False).xaxis.tick_bottom()

# %% [markdown]
# ### Males:  Create pivot tables for each sector Index = Region, Columns = Year & plot graphs

# %%
#pivot table for Business Analysts, Architects and System Designers
BA_Arch_SD_2 = males_copy.pivot('Region','Year','Business Analysts, Architects and System Designers')

# view the pivot table
BA_Arch_SD_2
# Out:
# Year                      2016-2017  2017-2018  2018-2019  2019-2020  \
# Region
# East                         8900.0    13700.0     9500.0     9300.0
# East Midlands                4600.0     5500.0     7600.0     8600.0
# London                      15900.0    26800.0    22100.0    33600.0
# North East                   1900.0     2100.0     3200.0     2400.0
# North West                   8400.0     8100.0     9600.0    10100.0
# Northern Ireland                NaN     1300.0        NaN     2200.0
# Scotland                     7100.0     9000.0     5000.0     6800.0
# South East                  23900.0    22300.0    22800.0    27600.0
# South West                   8900.0     6700.0     7400.0     9700.0
# Wales                        3700.0     3200.0     2100.0     3400.0
# West Midlands                4100.0     6300.0    10800.0    11000.0
# Yorkshire and The Humber     7900.0     5200.0     6500.0     8100.0
#
# Year                      2020-2021
# Region
# East                        14400.0
# East Midlands                8000.0
# London                      41900.0
# North East                      NaN
# North West                  16000.0
# Northern Ireland                NaN
# Scotland                    13800.0
# South East                  26600.0
# South West                  14700.0
# Wales                        5400.0
# West Midlands               13200.0
# Yorkshire and The Humber     9800.0

# %%
# bar plot based on the pivot table - Business Analysts, Architects and System Designers
ax = BA_Arch_SD_2.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)

plt.title('Business Analysts, Architects and System Designers')

plt.show()

# %%
#Correlation matrix for the pivot table - Business Analysts, Architects and System Designers
corrmat = BA_Arch_SD_2.corr()
corrmat

# %%
sns.heatmap(corrmat, vmax=1., square=False).xaxis.tick_bottom()

# %%
# pivot table for Information Technology and Telecommunications
IT_telcomm_2 = males_copy.pivot('Region','Year','Information Technology and Telecommunications')

# view the pivot table
IT_telcomm_2
# Out:
# Year                      2016-2017  2017-2018  2018-2019  2019-2020  \
# Region
# East                        11800.0     9400.0    12300.0    17100.0
# East Midlands                3800.0     5000.0     6200.0     3800.0
# London                      22300.0    18800.0    21100.0    16600.0
# North East                   2300.0     1600.0     1800.0     1900.0
# North West                   5600.0     6500.0     7700.0     9800.0
# Northern Ireland                NaN     1200.0        NaN      600.0
# Scotland                     4900.0     2700.0     5200.0     5000.0
# South East                  20400.0    21100.0    22400.0    22300.0
# South West                   8900.0     9100.0     5800.0     8400.0
# Wales                        1900.0     1400.0     3000.0     1800.0
# West Midlands                6500.0     3700.0     4400.0     6700.0
# Yorkshire and The Humber     5000.0     6100.0     6500.0    10900.0
#
# Year                      2020-2021
# Region
# East                        15200.0
# East Midlands                6400.0
# London                      28900.0
# North East                      NaN
# North West                   8900.0
# Northern Ireland                NaN
# Scotland                     3800.0
# South East                  24800.0
# South West                   7000.0
# Wales                        2100.0
# West Midlands               11000.0
# Yorkshire and The Humber     8000.0

# %%
# bar plot based on the pivot table Information Technology and Telecommunications
ax = IT_telcomm_2.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)

plt.title('Information Technology and Telecommunications')

plt.show()

# %%
#Correlation matric for the pivot table -Information Technology and Telecommunications 
corrmat = IT_telcomm_2.corr()
corrmat

# %%
sns.heatmap(corrmat, vmax=1., square=False).xaxis.tick_bottom()

# %%
# pivot table for Information Technology and Telecommunications Professionals n.e.c
IT_telcomm_nec_2 = males_copy.pivot('Region','Year','Information Technology and Telecommunications Professionals n.e.c')

# view the pivot table
IT_telcomm_nec_2
# Out:
# Year                      2016-2017  2017-2018  2018-2019  2019-2020  \
# Region
# East                        17600.0    16900.0    21600.0    12200.0
# East Midlands                9600.0     5500.0     8500.0    11300.0
# London                      41600.0    35700.0    38000.0    27300.0
# North East                   3700.0     4200.0     4900.0     5000.0
# North West                   9600.0    13200.0    13500.0    12800.0
# Northern Ireland                NaN     4500.0        NaN     2600.0
# Scotland                    10600.0     8600.0     7900.0     8900.0
# South East                  32700.0    34200.0    36000.0    36400.0
# South West                  14400.0    11200.0     9400.0    12600.0
# Wales                        4300.0     3200.0     3300.0     4800.0
# West Midlands               12600.0    10900.0    12400.0    12500.0
# Yorkshire and The Humber     9200.0     8500.0     6500.0     9700.0
#
# Year                      2020-2021
# Region
# East                        19600.0
# East Midlands               10300.0
# London                      36800.0
# North East                      NaN
# North West                  17500.0
# Northern Ireland                NaN
# Scotland                     9900.0
# South East                  33400.0
# South West                  13500.0
# Wales                        3300.0
# West Midlands               13700.0
# Yorkshire and The Humber    11100.0

# %%
# bar plot based on the pivot table Information Technology and Telecommunications Professionals n.e.c
ax = IT_telcomm_nec_2.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)

plt.title('Information Technology and Telecommunications Professionals n.e.c')

plt.show()

# %%
#Correlation matric for the pivot table -Information Technology and Telecommunications Professionals n.e.c
corrmat = IT_telcomm_2.corr()
corrmat

# %%
sns.heatmap(corrmat, vmax=1., square=False).xaxis.tick_bottom()

# %%
# pivot table for Programmers and Software Development Professionals
Prog_SoftDevProf_2 = males_copy.pivot('Region','Year','Programmers and Software Development Professionals')

# view the pivot table
Prog_SoftDevProf_2
# Out:
# Year                      2016-2017  2017-2018  2018-2019  2019-2020  \
# Region
# East                        25100.0    23800.0    32800.0    38800.0
# East Midlands               15300.0    14700.0    14500.0    12900.0
# London                      61300.0    65300.0    79600.0    81600.0
# North East                   8200.0     6900.0     8000.0     8300.0
# North West                  17600.0    19400.0    25600.0    30900.0
# Northern Ireland                NaN     8300.0        NaN     7800.0
# Scotland                    22300.0    22000.0    18900.0    20600.0
# South East                  48300.0    54500.0    56700.0    66100.0
# South West                  20100.0    20200.0    27300.0    24900.0
# Wales                        6800.0     7900.0     7800.0     8900.0
# West Midlands               14700.0    20700.0    19400.0    27200.0
# Yorkshire and The Humber    13800.0    16100.0    19100.0    18700.0
#
# Year                      2020-2021
# Region
# East                        41100.0
# East Midlands               18900.0
# London                      85100.0
# North East                      NaN
# North West                  38200.0
# Northern Ireland                NaN
# Scotland                    28100.0
# South East                  60800.0
# South West                  26900.0
# Wales                        9700.0
# West Midlands               26600.0
# Yorkshire and The Humber    26500.0

# %%
# bar plot based on the pivot table Programmers and Software Development Professionals
ax = Prog_SoftDevProf_2.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)

plt.title('Programmers and Software Development Professionals')

plt.show()

# %%
#corrlation Table of prog_Soft Dev Prof between all years
corrmat = Prog_SoftDevProf_2.corr()
corrmat

# %%
sns.heatmap(corrmat, vmax=1., square=False).xaxis.tick_bottom()

# %%
# pivot table for Project and Programme Managers
Project_ProgManagers_2 = males_copy.pivot('Region','Year','Project and Programme Managers')

# view the pivot table
Project_ProgManagers_2
# Out:
# Year                      2016-2017  2017-2018  2018-2019  2019-2020  \
# Region
# East                         6600.0     7300.0     2800.0     3700.0
# East Midlands                4200.0     3400.0     2900.0     3500.0
# London                      11800.0     9500.0     7900.0    18300.0
# North East                   1700.0     1100.0     1100.0      600.0
# North West                   5600.0     5100.0     3000.0     3600.0
# Northern Ireland                NaN     1200.0        NaN     1800.0
# Scotland                     4200.0     3000.0     4300.0     2500.0
# South East                  12100.0     9000.0     6700.0     9200.0
# South West                   6600.0     2400.0     2200.0     7600.0
# Wales                        1800.0     2100.0      800.0     1000.0
# West Midlands                2200.0     2700.0     2400.0     4400.0
# Yorkshire and The Humber     3500.0     3900.0     1400.0     3400.0
#
# Year                      2020-2021
# Region
# East                         5500.0
# East Midlands                3700.0
# London                       7100.0
# North East                      NaN
# North West                   6800.0
# Northern Ireland                NaN
# Scotland                     2800.0
# South East                  15200.0
# South West                   6600.0
# Wales                         700.0
# West Midlands                6900.0
# Yorkshire and The Humber     5000.0

# %%
# bar plot based on the pivot table Project and Programme Managers
ax = Project_ProgManagers_2.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)

plt.title('Project and Programme Managers')

plt.show()

# %%
#corrlation Table of Project_ProgManagers_2 between all years
corrmat = Project_ProgManagers_2.corr()
corrmat

# %%
sns.heatmap(corrmat, vmax=1., square=False).xaxis.tick_bottom()

# %%
# pivot table for Specialist Managers
Specialist_Managers_2 = males_copy.pivot('Region','Year','Specialist Managers')

# view the pivot table
Specialist_Managers_2
# Out:
# Year                      2016-2017  2017-2018  2018-2019  2019-2020  \
# Region
# East                        15800.0    13700.0    15100.0    21000.0
# East Midlands               10900.0     9600.0    10300.0    12200.0
# London                      26600.0    29300.0    37100.0    32300.0
# North East                   4100.0     2900.0     4400.0     4600.0
# North West                  12700.0    13600.0    13100.0    15500.0
# Northern Ireland                NaN     1600.0        NaN     1900.0
# Scotland                     8400.0    10100.0     9000.0    11500.0
# South East                  35800.0    29500.0    39800.0    26400.0
# South West                  12300.0    10400.0    11500.0     9900.0
# Wales                        5000.0     5200.0     5900.0     5800.0
# West Midlands               10500.0    10200.0     7100.0    14800.0
# Yorkshire and The Humber     7700.0    11500.0    11500.0    15400.0
#
# Year                      2020-2021
# Region
# East                        14000.0
# East Midlands               14100.0
# London                      35600.0
# North East                      NaN
# North West                  17000.0
# Northern Ireland                NaN
# Scotland                    16400.0
# South East                  34100.0
# South West                  12600.0
# Wales                        4200.0
# West Midlands               15600.0
# Yorkshire and The Humber    17600.0

# %%
# bar plot based on the pivot table Specialist Managers
ax = Specialist_Managers_2.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)

plt.title('Specialist Managers')

plt.show()

# %%
#corrlation Table of Specialist_Managers_2 between all years
corrmat = Specialist_Managers_2.corr()
corrmat

# %%
sns.heatmap(corrmat, vmax=1., square=False).xaxis.tick_bottom()

# %%
# pivot table for Web design and development professionals 
Web_design_dev_prof_2 = males_copy.pivot('Region','Year','Web design and development professionals')

# view the pivot table
Web_design_dev_prof_2
# Out:
# Year                      2016-2017  2017-2018  2018-2019  2019-2020  \
# Region
# East                         5600.0     3800.0     3500.0     6200.0
# East Midlands                4000.0     2600.0     1800.0     1000.0
# London                       8600.0     7800.0     8300.0     9700.0
# North East                   2100.0     1900.0     2100.0     1500.0
# North West                   5300.0     4700.0     2700.0     6400.0
# Northern Ireland                NaN      600.0        NaN     1300.0
# Scotland                     3100.0     2900.0     4500.0     3200.0
# South East                  10700.0     6700.0     6100.0     5500.0
# South West                   3500.0     3800.0     5100.0     8000.0
# Wales                        2100.0     1300.0     2200.0     1600.0
# West Midlands                1400.0     3700.0     4200.0     2600.0
# Yorkshire and The Humber     3600.0     3800.0     3000.0     2100.0
#
# Year                      2020-2021
# Region
# East                         7300.0
# East Midlands                1900.0
# London                       9500.0
# North East                      NaN
# North West                   6100.0
# Northern Ireland                NaN
# Scotland                     1800.0
# South East                   8300.0
# South West                   4000.0
# Wales                        1400.0
# West Midlands                3200.0
# Yorkshire and The Humber     4500.0

# %%
# bar plot based on the pivot table Web design and development professionals
ax = Web_design_dev_prof_2.plot(kind='bar')

fig = ax.get_figure()

fig.set_size_inches(15, 10)

plt.title('Web design and development professionals')

plt.show()

# %%
#corrlation Table of Web design and development professionals between all years
corrmat =  Web_design_dev_prof_2.corr()
corrmat

# %%
sns.heatmap(corrmat, vmax=1., square=False).xaxis.tick_bottom()

# %% [markdown]
# ### Percentage Change

# %% [markdown]
# ### Females

# %%
Project_ProgManagers_pct = (females_copy.pivot('Year','Region','Project and Programme Managers').pct_change()*100)

Specialist_Managers_pct = (females_copy.pivot('Year','Region','Specialist Managers').pct_change()*100)

# %%
print('Percentage change for female Specialist Managers')
Specialist_Managers_pct
# Out:
# Percentage change for female Specialist Managers
# Region           East  East Midlands     London  North East  North West  \
# Year
# 2016-2017         NaN            NaN        NaN         NaN         NaN
# 2017-2018   32.258065       0.000000   0.000000        70.0   15.625000
# 2018-2019  -39.024390     115.789474  -5.633803         0.0    5.405405
# 2019-2020  104.000000       0.000000  68.656716         0.0    0.000000
# 2020-2021   43.137255      -9.756098  30.973451         0.0   69.230769
#
# Region     Northern Ireland   Scotland  South East  South West       Wales  \
# Year
# 2016-2017               NaN        NaN         NaN         NaN         NaN
# 2017-2018               NaN  77.272727  -17.307692  -22.222222    0.000000
# 2018-2019               NaN -58.974359   83.720930   33.333333  100.000000
# 2019-2020               NaN  56.250000  -10.126582   28.571429  -50.000000
# 2020-2021               NaN  72.000000   12.676056   11.111111  122.222222
#
# Region     West Midlands  Yorkshire and The Humber
# Year
# 2016-2017            NaN                       NaN
# 2017-2018      -7.407407                 29.411765
# 2018-2019       0.000000                -31.818182
# 2019-2020      -4.000000                -50.000000
# 2020-2021      54.166667                140.000000

# %%
fig = plt.figure(figsize=(15,10))

ax = fig.add_subplot(431)
plt.plot(Specialist_Managers_pct['East'], color='Blue')

ax = fig.add_subplot(432)
plt.plot(Specialist_Managers_pct['East Midlands'], color='Orange')

ax = fig.add_subplot(433)
plt.plot(Specialist_Managers_pct['London'], color='Yellow')

ax = fig.add_subplot(434)
plt.plot(Specialist_Managers_pct['North East'], color='Green')

ax = fig.add_subplot(435)
plt.plot(Specialist_Managers_pct['North West'], color='Pink')

ax = fig.add_subplot(436)
plt.plot(Specialist_Managers_pct['Northern Ireland'], color='Teal')

ax = fig.add_subplot(437)
plt.plot(Specialist_Managers_pct['Scotland'], color='Grey')

ax = fig.add_subplot(438)
plt.plot(Specialist_Managers_pct['South East'], color='Black')

ax = fig.add_subplot(439)
plt.plot(Specialist_Managers_pct['South West'], color='Purple')

ax = fig.add_subplot(4,3,10)
plt.plot(Specialist_Managers_pct['Wales'], color='Red')

ax = fig.add_subplot(4,3,11)
plt.plot(Specialist_Managers_pct['West Midlands'], color='Brown')

ax = fig.add_subplot(4,3,12)
plt.plot(Specialist_Managers_pct['Yorkshire and The Humber'], color='Navy')

# %%
print('Percentage change for female Project and Programme Managers')
Project_ProgManagers_pct
# Out:
# Percentage change for female Project and Programme Managers
# Region          East  East Midlands      London  North East  North West  \
# Year
# 2016-2017        NaN            NaN         NaN         NaN         NaN
# 2017-2018 -33.333333       0.000000   -6.250000       -50.0  122.222222
# 2018-2019 -31.818182      88.888889  -60.000000         0.0    5.000000
# 2019-2020 -13.333333       0.000000  120.833333         0.0  -28.571429
# 2020-2021  61.538462       5.882353   20.754717         0.0   13.333333
#
# Region     Northern Ireland    Scotland  South East  South West      Wales  \
# Year
# 2016-2017               NaN         NaN         NaN         NaN        NaN
# 2017-2018               NaN   26.666667    2.380952  -27.272727   0.000000
# 2018-2019               NaN  -31.578947  -69.767442   12.500000   0.000000
# 2019-2020               NaN  -15.384615  115.384615   55.555556  66.666667
# 2020-2021               NaN  163.636364   53.571429   57.142857 -40.000000
#
# Region     West Midlands  Yorkshire and The Humber
# Year
# 2016-2017            NaN                       NaN
# 2017-2018       9.090909                137.500000
# 2018-2019       0.000000                -89.473684
# 2019-2020     116.666667                700.000000
# 2020-2021     -61.538462                 43.750000

# %%
fig = plt.figure(figsize=(15,10))

ax = fig.add_subplot(431)
plt.plot(Project_ProgManagers_pct['East'], color='Blue')

ax = fig.add_subplot(432)
plt.plot(Project_ProgManagers_pct['East Midlands'], color='Orange')

ax = fig.add_subplot(433)
plt.plot(Project_ProgManagers_pct['London'], color='Yellow')

ax = fig.add_subplot(434)
plt.plot(Project_ProgManagers_pct['North East'], color='Green')

ax = fig.add_subplot(435)
plt.plot(Project_ProgManagers_pct['North West'], color='Pink')

ax = fig.add_subplot(436)
plt.plot(Project_ProgManagers_pct['Northern Ireland'], color='Teal')

ax = fig.add_subplot(437)
plt.plot(Project_ProgManagers_pct['Scotland'], color='Grey')

ax = fig.add_subplot(438)
plt.plot(Project_ProgManagers_pct['South East'], color='Black')

ax = fig.add_subplot(439)
plt.plot(Project_ProgManagers_pct['South West'], color='Purple')

ax = fig.add_subplot(4,3,10)
plt.plot(Project_ProgManagers_pct['Wales'], color='Red')

ax = fig.add_subplot(4,3,11)
plt.plot(Project_ProgManagers_pct['West Midlands'], color='Brown')

ax = fig.add_subplot(4,3,12)
plt.plot(Project_ProgManagers_pct['Yorkshire and The Humber'], color='Navy')

# %% [markdown]
# ### Males

# %%
Project_ProgManagers_2_pct = (males_copy.pivot('Year','Region','Project and Programme Managers').pct_change()*100)

Specialist_Managers_2_pct = (males_copy.pivot('Year','Region','Specialist Managers').pct_change()*100)

# %%
print('Percentage change for male Specialist Managers')
Specialist_Managers_2_pct
# Out:
# Percentage change for male Specialist Managers
# Region          East  East Midlands     London  North East  North West  \
# Year
# 2016-2017        NaN            NaN        NaN         NaN         NaN
# 2017-2018 -13.291139     -11.926606  10.150376  -29.268293    7.086614
# 2018-2019  10.218978       7.291667  26.621160   51.724138   -3.676471
# 2019-2020  39.072848      18.446602 -12.938005    4.545455   18.320611
# 2020-2021 -33.333333      15.573770  10.216718    0.000000    9.677419
#
# Region     Northern Ireland   Scotland  South East  South West      Wales  \
# Year
# 2016-2017               NaN        NaN         NaN         NaN        NaN
# 2017-2018               NaN  20.238095  -17.597765  -15.447154   4.000000
# 2018-2019              0.00 -10.891089   34.915254   10.576923  13.461538
# 2019-2020             18.75  27.777778  -33.668342  -13.913043  -1.694915
# 2020-2021              0.00  42.608696   29.166667   27.272727 -27.586207
#
# Region     West Midlands  Yorkshire and The Humber
# Year
# 2016-2017            NaN                       NaN
# 2017-2018      -2.857143                 49.350649
# 2018-2019     -30.392157                  0.000000
# 2019-2020     108.450704                 33.913043
# 2020-2021       5.405405                 14.285714

# %%
fig = plt.figure(figsize=(15,10))

ax = fig.add_subplot(431)
plt.plot(Specialist_Managers_2_pct['East'], color='Blue')

ax = fig.add_subplot(432)
plt.plot(Specialist_Managers_2_pct['East Midlands'], color='Orange')

ax = fig.add_subplot(433)
plt.plot(Specialist_Managers_2_pct['London'], color='Yellow')

ax = fig.add_subplot(434)
plt.plot(Specialist_Managers_2_pct['North East'], color='Green')

ax = fig.add_subplot(435)
plt.plot(Specialist_Managers_2_pct['North West'], color='Pink')

ax = fig.add_subplot(436)
plt.plot(Specialist_Managers_2_pct['Northern Ireland'], color='Teal')

ax = fig.add_subplot(437)
plt.plot(Specialist_Managers_2_pct['Scotland'], color='Grey')

ax = fig.add_subplot(438)
plt.plot(Specialist_Managers_2_pct['South East'], color='Black')

ax = fig.add_subplot(439)
plt.plot(Specialist_Managers_2_pct['South West'], color='Purple')

ax = fig.add_subplot(4,3,10)
plt.plot(Specialist_Managers_2_pct['Wales'], color='Red')

ax = fig.add_subplot(4,3,11)
plt.plot(Specialist_Managers_2_pct['West Midlands'], color='Brown')

ax = fig.add_subplot(4,3,12)
plt.plot(Specialist_Managers_2_pct['Yorkshire and The Humber'], color='Navy')

# %%
print('Percentage change for male Project and Programme Managers')
Project_ProgManagers_2_pct
# Out:
# Percentage change for male Project and Programme Managers
# Region          East  East Midlands      London  North East  North West  \
# Year
# 2016-2017        NaN            NaN         NaN         NaN         NaN
# 2017-2018  10.606061     -19.047619  -19.491525  -35.294118   -8.928571
# 2018-2019 -61.643836     -14.705882  -16.842105    0.000000  -41.176471
# 2019-2020  32.142857      20.689655  131.645570  -45.454545   20.000000
# 2020-2021  48.648649       5.714286  -61.202186    0.000000   88.888889
#
# Region     Northern Ireland   Scotland  South East  South West      Wales  \
# Year
# 2016-2017               NaN        NaN         NaN         NaN        NaN
# 2017-2018               NaN -28.571429  -25.619835  -63.636364  16.666667
# 2018-2019               0.0  43.333333  -25.555556   -8.333333 -61.904762
# 2019-2020              50.0 -41.860465   37.313433  245.454545  25.000000
# 2020-2021               0.0  12.000000   65.217391  -13.157895 -30.000000
#
# Region     West Midlands  Yorkshire and The Humber
# Year
# 2016-2017            NaN                       NaN
# 2017-2018      22.727273                 11.428571
# 2018-2019     -11.111111                -64.102564
# 2019-2020      83.333333                142.857143
# 2020-2021      56.818182                 47.058824

# %%
fig = plt.figure(figsize=(15,10))

ax = fig.add_subplot(431)
plt.plot(Project_ProgManagers_2_pct['East'], color='Blue')

ax = fig.add_subplot(432)
plt.plot(Project_ProgManagers_2_pct['East Midlands'], color='Orange')

ax = fig.add_subplot(433)
plt.plot(Project_ProgManagers_2_pct['London'], color='Yellow')

ax = fig.add_subplot(434)
plt.plot(Project_ProgManagers_2_pct['North East'], color='Green')

ax = fig.add_subplot(435)
plt.plot(Project_ProgManagers_2_pct['North West'], color='Pink')

ax = fig.add_subplot(436)
plt.plot(Project_ProgManagers_2_pct['Northern Ireland'], color='Teal')

ax = fig.add_subplot(437)
plt.plot(Project_ProgManagers_2_pct['Scotland'], color='Grey')

ax = fig.add_subplot(438)
plt.plot(Project_ProgManagers_2_pct['South East'], color='Black')

ax = fig.add_subplot(439)
plt.plot(Project_ProgManagers_2_pct['South West'], color='Purple')

ax = fig.add_subplot(4,3,10)
plt.plot(Project_ProgManagers_2_pct['Wales'], color='Red')

ax = fig.add_subplot(4,3,11)
plt.plot(Project_ProgManagers_2_pct['West Midlands'], color='Brown')

ax = fig.add_subplot(4,3,12)
plt.plot(Project_ProgManagers_2_pct['Yorkshire and The Humber'], color='Navy')

# %% [markdown]
# ### Pie Charts to show the percentage of males and females in web design from 2016 - 2021

# %%
slices = [Web_design_dev_prof_2['2016-2017'].sum(), Web_design_dev_prof['2016-2017'].sum()]

activities = ['Males','Females']

cols = ['pink','green']

plt.pie(
    slices,
    labels=activities,
    colors=cols,
    startangle=90,
    shadow= True,
    explode=(0,0.1),
    autopct='%0.1f%%'
)
plt.title ('Web design and development professionals 2016-2017')
plt.show()

# %%
slices = [Web_design_dev_prof_2['2017-2018'].sum(), Web_design_dev_prof['2017-2018'].sum()]

activities = ['Males','Females']

cols = ['pink','green']

plt.pie(
    slices,
    labels=activities,
    colors=cols,
    startangle=90,
    shadow= True,
    explode=(0,0.1),
    autopct='%0.1f%%'
)
plt.title ('Web design and development professionals 2017 - 2018')
plt.show()

# %%
slices = [Web_design_dev_prof_2['2018-2019'].sum(), Web_design_dev_prof['2018-2019'].sum()]

activities = ['Males','Females']

cols = ['pink','green']

plt.pie(
    slices,
    labels=activities,
    colors=cols,
    startangle=90,
    shadow= True,
    explode=(0,0.1),
    autopct='%0.1f%%'
)
plt.title ('Web design and development professionals 2018-2019')
plt.show()

# %%
slices = [Web_design_dev_prof_2['2019-2020'].sum(), Web_design_dev_prof['2019-2020'].sum()]

activities = ['Males','Females']

cols = ['pink','green']

plt.pie(
    slices,
    labels=activities,
    colors=cols,
    startangle=90,
    shadow= True,
    explode=(0,0.1),
    autopct='%0.1f%%'
)
plt.title ('Web design and development professionals 2019-2020')
plt.show()

# %%
slices = [Web_design_dev_prof_2['2020-2021'].sum(), Web_design_dev_prof['2020-2021'].sum()]

activities = ['Males','Females']

cols = ['pink','green']

plt.pie(
    slices,
    labels=activities,
    colors=cols,
    startangle=90,
    shadow= True,
    explode=(0,0.1),
    autopct='%0.1f%%'
)
plt.title ('Web design and development professionals 2020-2021')
plt.show()

# %% [markdown]
# ## finding the correlation between Males and Females using different seaborn features.

# %% [markdown]
# ### 1- using hex bins

# %%
males_copy.columns
# Out:
# Index(['Region', 'Year', 'Information Technology and Telecommunications',
#        'Specialist Managers', 'Project and Programme Managers',
#        'Business Analysts, Architects and System Designers',
#        'Programmers and Software Development Professionals',
#        'Web design and development professionals',
#        'Information Technology and Telecommunications Professionals n.e.c'],
#       dtype='object')

# %%
#joinplot using hex bins to show the correlation between female  and male business Analyst, Architects and System Designers.

X=males_copy[ 'Business Analysts, Architects and System Designers']
Y=females_copy['Business Analysts, Architects and System Designers']
fig1= sns.jointplot(x=X,y=Y,kind="hex", color="red")
fig1.fig.suptitle('Male vs Female business Analyst, Architects and System Designers For All Years.')
plt.show()

# %%
#joinplot using hex bins to show the correlation between female and male Web Designers.

X=males_copy['Web design and development professionals']
Y=females_copy['Web design and development professionals']
fig1= sns.jointplot(x=X,y=Y,kind="hex", color="blue")
fig1.fig.suptitle('Male vs Female Web Designers For All Years.')
plt.show()

# %%
#joinplot using hex bins to show the correlation between female and male specialist Managers.

X=males_copy['Specialist Managers']
Y=females_copy['Specialist Managers']
fig1= sns.jointplot(x=X ,y=Y,kind="hex", color="orange")
fig1.fig.suptitle('Male vs Female specialist Managers For All Years.')
plt.show()

# %%
#joinplot using hex bins to show the correlation between female and male specialist Managers.

X=males_copy['Information Technology and Telecommunications']
Y=females_copy['Information Technology and Telecommunications']
fig1= sns.jointplot(x=X ,y=Y,kind="hex", color="yellow")
fig1.fig.suptitle('Male vs Female Information Technology and Telecommunications For All Years.')
plt.show()

# %%
#joinplot using hex bins to show the correlation between female and male Project and Programme Managers.

X=males_copy['Project and Programme Managers']
Y=females_copy['Project and Programme Managers']
fig1= sns.jointplot(x=X ,y=Y,kind="hex", color="indigo")
fig1.fig.suptitle('Male vs Female Project and Programme Managers For All Years.')
plt.show()

# %%
#joinplot using hex bins to show the correlation between female and male Programmers and Software Development Professionals.

X=males_copy['Programmers and Software Development Professionals']
Y=females_copy['Programmers and Software Development Professionals']
fig1= sns.jointplot(x=X ,y=Y,kind="hex", color="pink")
fig1.fig.suptitle('Male vs Female Programmers and Software Development Professionals For All Years.')
plt.show()

# %%
#joinplot using hex bins to show the correlation between female and male Programmers and Software Development Professionals.

X=males_copy['Information Technology and Telecommunications Professionals n.e.c']
Y=females_copy['Information Technology and Telecommunications Professionals n.e.c']
fig1= sns.jointplot(x=X ,y=Y,kind="hex", color="green")
fig1.fig.suptitle('Male vs FemaleInformation Technology and Telecommunications Professionals n.e.c')
plt.show()

# %%
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
# Histogram Plot showing dataset of specialist Managers in 2016-2017.
#darker colour shows the female data set whereas the lighter colour shows the male dataset
x = males_copy[males_copy['Year']=='2016-2017'].loc[:,"Specialist Managers"]
y = females_copy[females_copy['Year']=='2016-2017'].loc[:,"Specialist Managers"]
fig1, ax = plt.subplots()
for a in [x,y]:
    sns.histplot(a,ax=ax,kde=False,element = 'step')
plt.xlabel('Specialist Managers Salary')
plt.title('Specialist Managers Salary Distribution  for both genders in 2016-2017')
plt.show()

# Histogram Plot showing dataset of specialist Managers in 2020-2020.
#darker colour shows the female data set whereas the lighter colour shows the male dataset

# x1 = males_copy[males_copy['Year']=='2020-2021'].loc[:,"Specialist Managers"]
# y1 = females_copy[females_copy['Year']=='2020-2021'].loc[:,"Specialist Managers"]
# fig1, ax = plt.subplots()
# for a in [x1,y1]:
#     sns.histplot(a,ax=ax,kde=False,element = 'step', color = 'green')
# plt.xlabel('Male Specialist Managers Salary')
# plt.title('Specialist Managers Salary Distribution for both genders in 2020-2021')
# plt.show()


x = males_copy[males_copy['Year']=='2020-2021'].loc[:,"Specialist Managers"]
y = females_copy[females_copy['Year']=='2020-2021'].loc[:,"Specialist Managers"]
fig1, ax = plt.subplots()
for a in [x,y]:
    sns.histplot(a,ax=ax,kde=False,element = 'step',color ='green')
    plt.xlabel('Specialist Managers Salary')
plt.title('Specialist Managers Salary Distribution  for both genders in 2020-2021')
plt.show()
